# %%
from network import *
import numpy as np

# %%
nn = Network(
[
    Layer(2, 10, activation=relu, activation_der = relu_der),
    Layer(10, 1, activation=sigmoid, activation_der= sigmoid_der)
])



X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

nn.train(X, y, epochs=20000, lr=0.1)
print("Predicciones:")
print(nn.forward(X))
# Out:
# Predicciones:
# [[0.01857665]
#  [0.99172986]
#  [0.98949181]
#  [0.00847249]]
